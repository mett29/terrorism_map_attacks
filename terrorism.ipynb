# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import time
import warnings
warnings.filterwarnings('ignore')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
terror_data = pd.read_csv('globalterrorismdb_0616dist.csv', encoding='ISO-8859-1',
                          usecols=[0, 1, 2, 3, 8, 11, 13, 14, 35, 84, 100, 103])
terror_data = terror_data.rename(
    columns={'eventid':'id', 'iyear':'year', 'imonth':'month', 'iday':'day',
             'country_txt':'country', 'provstate':'state', 'targtype1_txt':'target',
             'weaptype1_txt':'weapon', 'nkill':'fatalities', 'nwound':'injuries'})

terror_data = terror_data.sort_values(['country'], ascending = False)

# %%
terror_data = terror_data[np.isfinite(terror_data.latitude)]
terror_data.head()
# Out:
#                  id  year  month  day   country               state  \
# 71903  200103040006  2001      3    0  Zimbabwe  Matabeleland North
# 30956  198705180003  1987      5   18  Zimbabwe              Harare
# 12231  198011160002  1980     11   16  Zimbabwe           Salisbury
# 13029  198103160004  1981      3   16  Zimbabwe            Masvingo
# 30889  198705090003  1987      5    9  Zimbabwe            Midlands
#
#         latitude  longitude                       target  \
# 71903 -19.860083  28.268742  Private Citizens & Property
# 30956 -17.825166  31.033510                     Business
# 12231 -17.860618  30.981896                     Business
# 13029 -20.063730  30.827660  Private Citizens & Property
# 30889 -19.698071  29.667207  Private Citizens & Property
#
#                           weapon  fatalities  injuries
# 71903                   Firearms         1.0       0.0
# 30956                   Firearms         1.0       0.0
# 12231  Explosives/Bombs/Dynamite         3.0      22.0
# 13029                   Firearms         2.0       0.0
# 30889                   Firearms         4.0       0.0

# %%
countries = list(set(terror_data.country))

country_mean_kills = []
for country in countries:
    country_mean_kills.append(terror_data.fatalities[terror_data.country == country].sum())

print('Number of people killed per attack by Country\n')
for i, country in enumerate(countries):
    print('{}:{}'.format(country, round(country_mean_kills[i],2)))
# Out:
# Average number of people killed per attack by Country
#
# North Korea:3.0
# St. Lucia:2.0
# Suriname:29.0
# Papua New Guinea:78.0
# Comoros:1.0
# Slovenia:1.0
# Bhutan:9.0
# International:1.0
# Afghanistan:26889.0
# Romania:4.0
# Chad:801.0
# Australia:19.0
# Colombia:13378.0
# Zambia:49.0
# Slovak Republic:7.0
# Trinidad and Tobago:6.0
# Macau:1.0
# Estonia:3.0
# Guyana:41.0
# Bosnia-Herzegovina:79.0
# Mauritania:43.0
# Cambodia:493.0
# Nicaragua:7262.0
# Democratic Republic of the Congo:2882.0
# Ethiopia:1189.0
# East Timor:8.0
# Paraguay:42.0
# Mozambique:2508.0
# Malta:3.0
# Belgium:40.0
# Norway:79.0
# United Arab Emirates:123.0
# Dominica:3.0
# China:998.0
# Ireland:114.0
# New Zealand:0.0
# Turkmenistan:3.0
# Israel:1634.0
# Chile:226.0
# Eritrea:42.0
# Austria:28.0
# Japan:44.0
# Brunei:0.0
# Bangladesh:982.0
# Yemen:6470.0
# Iceland:0.0
# Ukraine:2165.0
# Guinea-Bissau:17.0
# Portugal:32.0
# Guadeloupe:8.0
# Lithuania:1.0
# South Yemen:0.0
# Bahamas:1.0
# Somalia:6613.0
# Macedonia:49.0
# Laos:21.0
# Syria:10329.0
# Panama:38.0
# Libya:1641.0
# Bolivia:36.0
# Rwanda:3142.0
# Kosovo:81.0
# Wallis and Futuna:0.0
# Peru:11290.0
# Antigua and Barbuda:nan
# Namibia:206.0
# Greece:255.0
# Kuwait:60.0
# Czechoslovakia:1.0
# Barbados:76.0
# El Salvador:11159.0
# India:17644.0
# Costa Rica:17.0

# %%
data = [ dict(
        type = 'choropleth',
        locations = countries,
        z = country_mean_kills,
        locationmode = 'country names',
        text = countries,
        marker = dict(
            line = dict(color = 'rgb(0,0,0)', width = 1)),
            colorbar = dict(autotick = True, tickprefix = '', 
            title = '# Number of\nKills')
            )
       ]

layout = dict(
    title = 'Number of people killed per attack by Country (1970 - 2015)',
    geo = dict(
        showframe = False,
        showocean = True,
        oceancolor = 'rgb(0,255,255)',
        projection = dict(
        type = 'orthographic',
            rotation = dict(
                    lon = 60,
                    lat = 10),
        ),
        lonaxis =  dict(
                showgrid = True,
                gridcolor = 'rgb(102, 102, 102)'
            ),
        lataxis = dict(
                showgrid = True,
                gridcolor = 'rgb(102, 102, 102)'
                )
            ),
        )

fig = dict(data=data, layout=layout)
py.iplot(fig, validate=False, filename='worldmap')
# Out:
# <div id="d4d4b2e5-1da9-4f3a-a9ff-6b91326a1dde" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d4d4b2e5-1da9-4f3a-a9ff-6b91326a1dde", [{"locations": ["North Korea", "St. Lucia", "Suriname", "Papua New Guinea", "Comoros", "Slovenia", "Bhutan", "International", "Afghanistan", "Romania", "Chad", "Australia", "Colombia", "Zambia", "Slovak Republic", "Trinidad and Tobago", "Macau", "Estonia", "Guyana", "Bosnia-Herzegovina", "Mauritania", "Cambodia", "Nicaragua", "Democratic Republic of the Congo", "Ethiopia", "East Timor", "Paraguay", "Mozambique", "Malta", "Belgium", "Norway", "United Arab Emirates", "Dominica", "China", "Ireland", "New Zealand", "Turkmenistan", "Israel", "Chile", "Eritrea", "Austria", "Japan", "Brunei", "Bangladesh", "Yemen", "Iceland", "Ukraine", "Guinea-Bissau", "Portugal", "Guadeloupe", "Lithuania", "South Yemen", "Latvia", "Denmark", "Indonesia", "Italy", "Ivory Coast", "Tanzania", "Soviet Union", "Belize", "Kazakhstan", "Iran", "Nigeria", "Bahrain", "Zimbabwe", "Ghana", "Lesotho", "Dominican Republic", "St. Kitts and Nevis", "Western Sahara", "Burundi", "Cameroon", "Canada", "Azerbaijan", "Sierra Leone", "Senegal", "Myanmar", "People's Republic of the Congo", "Czech Republic", "Hong Kong", "East Germany (GDR)", "Gabon", "Mauritius", "United States", "Malawi", "Bulgaria", "Poland", "Yugoslavia", "Republic of the Congo", "United Kingdom", "Morocco", "South Korea", "Albania", "Tajikistan", "Botswana", "Angola", "Martinique", "Guatemala", "Kyrgyzstan", "New Caledonia", "Pakistan", "Solomon Islands", "Iraq", "Gambia", "Swaziland", "Zaire", "Germany", "Switzerland", "Serbia-Montenegro", "Netherlands", "Saudi Arabia", "Togo", "Seychelles", "Jordan", "Jamaica", "Gibraltar", "Fiji", "Cuba", "Taiwan", "Burkina Faso", "Russia", "Kenya", "Qatar", "Singapore", "Montenegro", "Maldives", "Hungary", "Belarus", "Uganda", "North Yemen", "French Polynesia", "Sudan", "Moldova", "Madagascar", "Benin", "Uzbekistan", "Uruguay", "Mali", "Honduras", "Mexico", "Tunisia", "West Bank and Gaza Strip", "Venezuela", "Falkland Islands", "South Africa", "Vietnam", "Turkey", "Ecuador", "Grenada", "South Vietnam", "Brazil", "French Guiana", "Croatia", "Finland", "Niger", "Malaysia", "Vanuatu", "Vatican City", "Spain", "New Hebrides", "Sweden", "Serbia", "Haiti", "Philippines", "Cyprus", "Liberia", "Lebanon", "Egypt", "Luxembourg", "Sri Lanka", "Rhodesia", "Guinea", "France", "Djibouti", "Equatorial Guinea", "Georgia", "West Germany (FRG)", "Central African Republic", "Armenia", "Algeria", "South Sudan", "Argentina", "Thailand", "Nepal", "Bahamas", "Somalia", "Macedonia", "Laos", "Syria", "Panama", "Libya", "Bolivia", "Rwanda", "Kosovo", "Wallis and Futuna", "Peru", "Antigua and Barbuda", "Namibia", "Greece", "Kuwait", "Czechoslovakia", "Barbados", "El Salvador", "India", "Costa Rica"], "marker": {"line": {"color": "rgb(0,0,0)", "width": 1}}, "z": [3.0, 2.0, 29.0, 78.0, 1.0, 1.0, 9.0, 1.0, 26889.0, 4.0, 801.0, 19.0, 13378.0, 49.0, 7.0, 6.0, 1.0, 3.0, 41.0, 79.0, 43.0, 493.0, 7262.0, 2882.0, 1189.0, 8.0, 42.0, 2508.0, 3.0, 40.0, 79.0, 123.0, 3.0, 998.0, 114.0, 0.0, 3.0, 1634.0, 226.0, 42.0, 28.0, 44.0, 0.0, 982.0, 6470.0, 0.0, 2165.0, 17.0, 32.0, 8.0, 1.0, 0.0, 2.0, 4.0, 1162.999998203, 412.0, 235.0, 36.0, 90.0, 1.0, 29.0, 1606.0, 18486.0, 37.0, 151.0, 10.0, 35.0, 32.0, 0.0, 0.0, 3271.0, 1798.0, 343.0, 188.0, 817.999999999, 206.0, 725.0, 15.0, 6.0, 4.0, 2.0, 6.0, 0.0, 3577.0, 33.0, 28.0, 7.0, 119.0, 151.0, 3395.0, 285.0, 10.0, 42.0, 282.0, 11.0, 2576.0, 0.0, 5025.0, 9.0, 34.0, 21473.0, 4.0, 58447.0, 13.0, 2.0, 155.0, 61.0, 74.0, 3.0, 33.0, 479.0, 72.0, 0.0, 93.0, 37.0, 3.0, 8.0, 8.0, 35.0, 8.0, 4181.0, 1617.0, 4.0, 5.0, 1.0, 0.0, 6.0, 14.0, 2885.0, 1.0, 0.0, 3410.9999999780002, 11.0, 28.0, 0.0, 68.0, 5.0, 741.0, 295.0, 749.0, 273.0, 1369.0, 207.0, null, 2509. ...
